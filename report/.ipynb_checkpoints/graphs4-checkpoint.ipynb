# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import glob
import csv

# %%
def read_results(pattern):
    data = pd.DataFrame({})
    for file in glob.glob(pattern):
        print(file)
        raw = pd.read_csv(file, skipfooter=2)
        if (data.empty):
            data = raw
            print(len(raw))
        else:
            data = data.merge(raw, left_index=True, right_index=True, how='outer')
    return data

optimum_price = 3730

def get_stats(pattern):
    for file in glob.glob(pattern):

        with open(file,"r") as f:
            reader = csv.reader(f,delimiter = ",")
            data = list(reader)
            row_count = len(data)

        df = pd.read_csv(file, skiprows = row_count - 2)
        print(file)        
        print(df)
        print("-------")

# %%
# ax = read_results("../csvs/genetic/elitism_count*")
bx = get_stats("../csvs/genetic/elitism_count*")
# Out:
#                            price  variables  clausules  satisfied  weight
# 0  9828.04349158547 20 70 70 783        NaN        NaN        NaN     NaN
#                            price  variables  clausules  satisfied  weight
# 0  9828.04349158547 20 70 70 783        NaN        NaN        NaN     NaN
#                            price  variables  clausules  satisfied  weight
# 0  9828.04349158547 20 70 70 783        NaN        NaN        NaN     NaN
#                            price  variables  clausules  satisfied  weight
# 0  9828.04349158547 20 70 70 783        NaN        NaN        NaN     NaN
#                            price  variables  clausules  satisfied  weight
# 0  9828.04349158547 20 70 70 783        NaN        NaN        NaN     NaN
#                            price  variables  clausules  satisfied  weight
# 0  9828.04349158547 20 70 70 783        NaN        NaN        NaN     NaN
#                            price  variables  clausules  satisfied  weight
# 0  9756.49324545962 20 70 70 698        NaN        NaN        NaN     NaN
#                            price  variables  clausules  satisfied  weight
# 0  9828.04349158547 20 70 70 783        NaN        NaN        NaN     NaN
#                            price  variables  clausules  satisfied  weight
# 0  9828.04349158547 20 70 70 783        NaN        NaN        NaN     NaN
#                            price  variables  clausules  satisfied  weight
# 0  9828.04349158547 20 70 70 783        NaN        NaN        NaN     NaN

# %%
ax
# Out:
#      generation_x  best_combination_ec_50  generation_y  \
# 0               0             9345.286387             0
# 1               1             9345.286387             1
# 2               2             9409.071366             2
# 3               3             9409.071366             3
# 4               4             9409.071366             4
# 5               5             9409.071366             5
# 6               6             9409.071366             6
# 7               7             9409.071366             7
# 8               8             9409.071366             8
# 9               9             9409.071366             9
# 10             10             9409.071366            10
# 11             11             9409.071366            11
# 12             12             9409.071366            12
# 13             13             9409.071366            13
# 14             14             9409.071366            14
# 15             15             9409.071366            15
# 16             16             9409.071366            16
# 17             17             9409.071366            17
# 18             18             9409.071366            18
# 19             19             9409.071366            19
# 20             20             9409.071366            20
# 21             21             9409.071366            21
# 22             22             9409.071366            22
# 23             23             9409.071366            23
# 24             24             9409.071366            24
# 25             25             9409.071366            25
# 26             26             9409.071366            26
# 27             27             9409.071366            27
# 28             28             9409.071366            28
# 29             29             9409.071366            29
# ..            ...                     ...           ...
# 970           970             9828.043492           970
# 971           971             9828.043492           971
# 972           972             9828.043492           972
# 973           973             9828.043492           973
# 974           974             9828.043492           974
# 975           975             9828.043492           975
# 976           976             9828.043492           976
# 977           977             9828.043492           977
# 978           978             9828.043492           978
# 979           979             9828.043492           979
# 980           980             9828.043492           980
# 981           981             9828.043492           981
# 982           982             9828.043492           982
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-ec3473f97830> in <module>
#       1 ax = read_results("../../csvs/genetic/elitism_count*")
# ----> 2 ax = ax.loc[:, ax.columns.str.contains('best_combination')]
#       3 ax = ax.reindex(sorted(ax.columns), axis=1)
#       4 plot= ax.plot(title="Elitism count")
#       5 plot.axhline(y=optimum_price, xmin=-1, xmax=1, color='limegreen', linestyle='--', lw=1)
#
# ~/repos/fit-knapsack-problem/__venv__/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# --> 133         accessor_obj = self._accessor(obj)
#     134         # Replace the property with the accessor object. Inspired by:
#     135         # http://www.pydanny.com/cached-property.html
#
# ~/repos/fit-knapsack-problem/__venv__/lib/python3.7/site-packages/pandas/core/strings.py in __init__(self, data)
#    1893
#    1894     def __init__(self, data):
# -> 1895         self._validate(data)
#    1896         self._is_categorical = is_categorical_dtype(data)
#    1897
#
# ~/repos/fit-knapsack-problem/__venv__/lib/python3.7/site-packages/pandas/core/strings.py in _validate(data)
#    1931                            "(i.e. inferred_type is 'string', 'unicode' or "
#    1932                            "'mixed')")
# -> 1933                 raise AttributeError(message)
#    1934             if data.nlevels > 1:
#    1935                 message = ("Can only use .str accessor with Index, not "
#
# AttributeError: Can only use .str accessor with string values (i.e. inferred_type is 'string', 'unicode' or 'mixed')

# %%
ax = read_results("../../csvs/genetic/elitism_count*")
ax
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
ax = read_results("../../csvs/genetic/generations*")
ax = ax.loc[:, ax.columns.str.contains('best_combination')]
ax = ax.reindex(sorted(ax.columns), axis=1)
plot= ax.plot(title="No. of Generations")
plot.axhline(y=optimum_price, xmin=-1, xmax=100, color='limegreen', linestyle='--', lw=1)
plot.set_xlabel("Generations")
plot.set_ylabel("Best price of item combinations")
plt.savefig('graphs/generations', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-ac2103e57466> in <module>
#       1 ax = read_results("../../csvs/genetic/generations*")
# ----> 2 ax = ax.loc[:, ax.columns.str.contains('best_combination')]
#       3 ax = ax.reindex(sorted(ax.columns), axis=1)
#       4 plot= ax.plot(title="No. of Generations")
#       5 plot.axhline(y=optimum_price, xmin=-1, xmax=100, color='limegreen', linestyle='--', lw=1)
#
# ~/repos/fit-knapsack-problem/__venv__/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# --> 133         accessor_obj = self._accessor(obj)
#     134         # Replace the property with the accessor object. Inspired by:
#     135         # http://www.pydanny.com/cached-property.html
#
# ~/repos/fit-knapsack-problem/__venv__/lib/python3.7/site-packages/pandas/core/strings.py in __init__(self, data)
#    1893
#    1894     def __init__(self, data):
# -> 1895         self._validate(data)
#    1896         self._is_categorical = is_categorical_dtype(data)
#    1897
#
# ~/repos/fit-knapsack-problem/__venv__/lib/python3.7/site-packages/pandas/core/strings.py in _validate(data)
#    1931                            "(i.e. inferred_type is 'string', 'unicode' or "
#    1932                            "'mixed')")
# -> 1933                 raise AttributeError(message)
#    1934             if data.nlevels > 1:
#    1935                 message = ("Can only use .str accessor with Index, not "
#
# AttributeError: Can only use .str accessor with string values (i.e. inferred_type is 'string', 'unicode' or 'mixed')

# %%
ax = read_results("../../csvs/genetic/mutation_probability*")
ax = ax.loc[:, ax.columns.str.contains('best_combination')]
ax = ax.reindex(sorted(ax.columns), axis=1)
plot= ax.plot(title="Mutation Probability")
plot.axhline(y=optimum_price, xmin=-1, xmax=1, color='limegreen', linestyle='--', lw=1)
plot.set_xlabel("Generations")
plot.set_ylabel("Best price of item combinations")
plt.savefig('graphs/mutation_probability', bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-f735adc29ed4> in <module>
#       1 ax = read_results("../../csvs/genetic/mutation_probability*")
# ----> 2 ax = ax.loc[:, ax.columns.str.contains('best_combination')]
#       3 ax = ax.reindex(sorted(ax.columns), axis=1)
#       4 plot= ax.plot(title="Mutation Probability")
#       5 plot.axhline(y=optimum_price, xmin=-1, xmax=1, color='limegreen', linestyle='--', lw=1)
#
# ~/repos/fit-knapsack-problem/__venv__/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     131             # we're accessing the attribute of the class, i.e., Dataset.geo
#     132             return self._accessor
# --> 133         accessor_obj = self._accessor(obj)
#     134         # Replace the property with the accessor object. Inspired by:
#     135         # http://www.pydanny.com/cached-property.html
#
# ~/repos/fit-knapsack-problem/__venv__/lib/python3.7/site-packages/pandas/core/strings.py in __init__(self, data)
#    1893
#    1894     def __init__(self, data):
# -> 1895         self._validate(data)
#    1896         self._is_categorical = is_categorical_dtype(data)
#    1897
#
# ~/repos/fit-knapsack-problem/__venv__/lib/python3.7/site-packages/pandas/core/strings.py in _validate(data)
#    1931                            "(i.e. inferred_type is 'string', 'unicode' or "
#    1932                            "'mixed')")
# -> 1933                 raise AttributeError(message)
#    1934             if data.nlevels > 1:
#    1935                 message = ("Can only use .str accessor with Index, not "
#
# AttributeError: Can only use .str accessor with string values (i.e. inferred_type is 'string', 'unicode' or 'mixed')

# %%
ax = read_results("../../csvs/genetic/tournament_count*")
ax = ax.loc[:, ax.columns.str.contains('best_combination')]
ax = ax.reindex(sorted(ax.columns), axis=1)
plot= ax.plot(title="Tournament count")
plot.axhline(y=optimum_price, xmin=-1, xmax=1, color='limegreen', linestyle='--', lw=1)
plot.set_xlabel("Generations")
plot.set_ylabel("Best price of item combinations")
plt.savefig('graphs/tournament_count', bbox_inches='tight')
# Out:
# 1000

# %%
ax = read_results("../../csvs/genetic/tournament_pool_size*")
ax = ax.loc[:, ax.columns.str.contains('best_combination')]
ax = ax.reindex(sorted(ax.columns), axis=1)
plot= ax.plot(title="Tournament pool size")
plot.axhline(y=optimum_price, xmin=-1, xmax=1, color='limegreen', linestyle='--', lw=1)
plot.set_xlabel("Generations")
plot.set_ylabel("Best price of item combinations")
plt.savefig('graphs/tournament_pool_size', bbox_inches='tight')
# Out:
# 1000

# %%
ax = read_results("../../csvs/genetic/xover_probability*")
ax = ax.loc[:, ax.columns.str.contains('best_combination')]
ax = ax.reindex(sorted(ax.columns), axis=1)
plot= ax.plot(title="Crossover probability")
plot.axhline(y=optimum_price, xmin=-1, xmax=1, color='limegreen', linestyle='--', lw=1)
plot.set_xlabel("Generations")
plot.set_ylabel("Best price of item combinations")
plt.savefig('graphs/xover_probability', bbox_inches='tight')
# Out:
# 1000
